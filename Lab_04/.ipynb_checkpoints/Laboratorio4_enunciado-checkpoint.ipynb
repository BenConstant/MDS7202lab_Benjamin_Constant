# %% [markdown]
# <h1><center>Laboratorio 4: El Pandas no muerde (act. I) 🐼</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Benjamin Constant
# - Nombre de alumno 2:

# %% [markdown]
# ### **Link de repositorio de GitHub:** `http://....`

# %% [markdown]
# ### Reglas:
#
# - **Grupos de 2 personas**
# - Asistencia **obligatoria** a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.
# - **Ausentes tienen nota máxima 6.0**.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Prohibidas las copias.
# - Pueden usar cualquer matrial del curso que estimen conveniente.

# %% [markdown]
# ### Temas a tratar
#
# - Introducción al manejo de datos tabulares por medio de la libreria `pandas`.

# %% [markdown]
# ### Objetivos principales del laboratorio
#
# - Entender, aplicar y aprovechar las ventajas que nos ofrece la libreria `pandas` para manejar datos tabulares.
# - Aprender a utilizar la documentación de pandas (y en general, de cualquier librería de python) como también a buscar soluciones en la web.
#
# > **Nota**: El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `pandas`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre DataFrames.

# %% [markdown]
# ### Librerias utiles para el Lab 😸

# %%
# Libreria Core del lab.
import numpy as np
import pandas as pd
from IPython.display import display

#Libreria para plotear
# !pip install --upgrade plotly
import plotly.express as px

# Librerias utiles
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: plotly in c:\users\bconstant\anaconda3\envs\sqm\lib\site-packages (5.17.0)
# Requirement already satisfied: packaging in c:\users\bconstant\anaconda3\envs\sqm\lib\site-packages (from plotly) (22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\bconstant\anaconda3\envs\sqm\lib\site-packages (from plotly) (8.2.2)

# %% [markdown]
# # 1. Rendimiento en Estudiantes 📚

# %% [markdown]
# Para este laboratorio deberán trabajar con el dataset `students_grades.json` el cual contiene información sobre el rendimiento de alumnos en distintos ramos.
# El objetivo principal será el de realizar un trabajo de limpieza de prepración y exploración de datos utilizando exclusivamente `DataFrames` y sus métodos asociados.

# %%
# Si usted está utilizando Colabolatory le puede ser útil este código para cargar los archivos.
try:
    from google.colab import drive
    drive.mount("/content/drive")
    path = 'Dirección donde tiene los archivos en el Drive'
except: 
    print('Ignorando conexión drive-colab')
# Out:
# Ignorando conexión drive-colab

# %% [markdown]
# ## 1.1 Carga e Inspección de Datos [1.5 Puntos]
#
#
# <p align="center">
#   <img src="https://drive.google.com/uc?export=view&id=1hZZaPQlZe4VupFOXt76_wjuUA5NpUhrw" width="300" height="300">
# </p>

# %% [markdown]
# *Don Caguayo*, rector de la Universidad de la Cachaña, les comenta que actualmente la Universidad no tiene una subdirección de análisis de datos, pero que tiene un gran interés en formar una. Es por esto, que se contacta con ud. y su equipo para iniciar de forma exploratoria diversas tareas de análisis y consolidación de datos respectivos al rendimiento de sus alumnos.
#
# Previo a su primera reunión con el rector, el rector le envía una copia de la base de datos, la cuál a usted y su equipo le encantaría examinar. Para esto, la primera tarea que debe realizar es abrir y cargar el dataset.
#
#
# > **Notar que es sumamente importante el formato que posee cada columna** para su manipulación y que posiblemente ustedes deberán especificar algunos tipos de datos a mano. Ver la documentación del método `read_json` para mayor información.
#
# A continuación se muestra un ejemplo de los dos primeros registros del dataset:
#
# ```json
# [
#   {
#     "names": "Rita Courtney",
#     "gender": "female",
#     "race/ethnicity": "group B",
#     "parental level of education": "some high school",
#     "lunch": "standard",
#     "test preparation course": "none",
#     "math score": 37,
#     "reading score": 46,
#     "writing score": 46
#   },
#   {
#     "names": "Madeline Fuller",
#     "gender": "female",
#     "race/ethnicity": "group C",
#     "parental level of education": "some high school",
#     "lunch": "standard",
#     "test preparation course": "none",
#     "math score": 124,
#     "reading score": 142,
#     "writing score": 142
#   }
# ]
# ```

# %%
df_grades = pd.read_json('students_grades.json',orient='records')
df_grades[df_grades==''] = np.nan#[df_grades[['math score','reading score','writing score']]<101]
#%matplotlib notebook
#df_grades.mask((df_grades.duplicated(subset=['names']))|(df_grades['math score']>100)|(df_grades['reading score']>100)|(df_grades['writing score']>100)).dropna()

# %% [markdown]
# <p align="center">
#   <img src="https://i.giphy.com/media/4FQMuOKR6zQRO/giphy.webp">
# </p>
#
#
# Posteriormente, el rector les comenta que la sección de TI posee una base de datos con más de **875** filas, en donde cada fila representa un alumno matriculado. Sin embargo, cree fuertemente que existen errores en esta: solo tiene registro de **875** matriculas. Por este motivo, especula que se han realizado malas prácticas al registrar dichos datos.
#
# En consecuencia, el rector les solicita a ustedes como tarea inicial que exploren la base de datos y encuentre posibles falencias dentro de sus registros. Para esto, usted debe estar al tanto que las notas están en una escala que van del **0 al 100** (porcentaje de logro) y **no es posible que un alumno haya dado más de una vez el mismo examen**. Cualquier alumno que posea un valor diferente a esta escala, debería ser eliminado de la base de datos.

# %% [markdown]
# > **Instrucciones**
#
# **Cree una función** que tome un `DataFrame` y que le permita revisar si las diferentes variables que lo componen son coherentes y si es posible observar anomalías en estas.
#
# **To-Do**
# 1. [ ] Imprimir un mensaje con las dimensiones del Dataframe.
# 2. [ ] Imprimir un mensaje con los nombres de las columnas que conforman el DataFrame.
# 3. [ ] Mostrar los primeros 5, los últimos 5 elementos del DataFrame y realice un muestreo de 5 elementos de forma aleatoria.
# 4. [ ] Mostrar una descripción rápida de las variables numéricas del DataFrame (utilice un método visto en clases).
# 5. [ ] Imprimir un mensaje con la cantidad de valores nulos (investigue el método `isna()` y `sum()` de los DataFrames).
# 6. [ ] Imprimir un mensaje que detalle la cantidad de valores unicos (investigue `nunique()`) .
# 7. [ ] Imprimir un mensaje con el total de filas que contengan nombres duplicados (investigue `duplicated()` y su parámetro `subset`).
# 8. [ ] Mostrar las filas que contengan nombres sean duplicados (investigue `duplicated()` y su parámetro `subset`).
# 9. [ ] A traves de `.plot.box()` plotear el boxplot de las notas. De ser necesario, invetigue como funcionan los gráficos de caja (esta sección es provista).
# 10. [ ] Finalmente responda la siguiente pregunta:
#
# > ¿Que anomalias es posible observar de los datos que componen el DataFrame? ¿Existen valores nulos o duplicados? ¿Qué puede interpretar de la distribución de las notas en el boxplot? (), comente esto en la celda ubicada debajo de **justificación**.
#
# > **Nota:** Para imprmir utilice `print(...)`. Para mostrar `DataFrames`, utilice `display(...)` ya que este permite mostrar estos elementos como tablas.
#
# > **Nota 2:** Utilice la documentación de [pandas](https://pandas.pydata.org/docs/index.html) como también StackOverflow para resolver cualquier problema o inconveniente.
#
# > **Nota 3:** Si no ha trabajado con boxplot antes, el siguiente link puede serle de mucha ayuda: [boxplot](https://medium.com/dayem-siddiqui/understanding-and-interpreting-box-plots-d07aab9d1b6c)

# %% [markdown]
# **Respuesta:**

# %%
def exploratory_data_analysis(dataframe):
    print(f'1.- El Dataframe tiene {dataframe.shape[0]} filas y {dataframe.shape[1]} columnas\n')
    columnas_df = dataframe.columns
    print(f'2.- El DataFrame esta compuesto por las siguientes columnas: {columnas_df}\n')
    print('3.- Ejemplos de filas del DataFrame:')
    print('Primeras 5 filas\n')
    display(dataframe.head(5))
    print(' ')
    print('Últimas 5 filas:\n')
    display(dataframe.tail(5))
    print(' ')
    print('Muestreo aleatorio de 5 filas:\n')
    display(dataframe.sample(5))
    print('4.- Descripción numérica del Dataframe:\n')
    display(dataframe.describe())
    print('5.- Cantidad de valores nulos por columna:\n')
    display(dataframe.isna().sum())
    print('6.- Cantidad de valores únicos por columna:\n')
    display(dataframe.nunique())
    Filas_duplicadas = dataframe.duplicated(subset=['names']).sum()
    print(f'7.- Presenta un total de {Filas_duplicadas} filas con nombres duplicados.\n')
    print(f'8.- Las filas con nombres duplicados son:')
    display(dataframe[dataframe.duplicated(subset=['names'])])
    print('9.- Boxplot de notas:\n')
    dataframe.dropna().plot.box(column=['math score','reading score','writing score'],figsize=(10,8))

# %% [markdown]
# **Justificación:**

# %% [markdown]
# ```
# 1.- Usando la funcion shape, se puede obtener la fila y la columna del dataframe siendo shape[0] y shape[1], la fila y la columna, respectivamente.
# 2.- Usando la funcion columns, se obtienen los nombres de las columnas del dataframe
# 3.- Para mostrar las primeras filas, se usa head(n) en donde n es la cantidad de filas que quiero ver. Para mostrar las ultimas filas, se usa tail(n) y para mostrar lineas randoms se usa sample(n), en donde n es el numero de filas que deseo mostrar
# 4.-Usando la funcion describe() se generan cuatro variables para cada columna, siendo la cantidad de datos no nan, datos unicos, el primer dato y la frecuencia del valor que mas se repite.
# 5.- Con la funcion isna(), se buscan los datos nan y con la subfuncion sum(), sumamos la cantidad de datos nan.
# 6.- Con la funcion nunique(), me permite mostrar los datos que no se repiten.
# 7.- Con la funcion duplicated, encuentro todos los datos que se duplican entre las filas y con la subfuncion sum(), obtenod la cantidad de datos duplicados.
# 8.- con la funcion duplicated, se obtienen los nombres que se repiten.
# 9.- Elimando los datos nan con la funcion dropna(), se plotean las notas de cada uno de los estudiantes en el formato box, para ver de forma grafica la dispersion de los datos.
# ```

# %% [markdown]
# **Respuesta Esperada:**

# %%
exploratory_data_analysis(df_grades)
# Out:
# 1.- El Dataframe tiene 1400 filas y 9 columnas
#
# 2.- El DataFrame esta compuesto por las siguientes columnas: Index(['names', 'gender', 'race/ethnicity', 'parental level of education',
#        'lunch', 'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')
#
# 3.- Ejemplos de filas del DataFrame:
# Primeras 5 filas
#               names  gender race/ethnicity parental level of education  \
# 0     Rita Courtney  female        group B            some high school
# 1   Madeline Fuller  female        group C            some high school
# 2     Daniel Rester    male        group E          associate's degree
# 3  Charles Linstrom    male        group A           bachelor's degree
# 4    Geraldine Hale  female        group A          associate's degree
#
#       lunch test preparation course math score reading score writing score
# 0  standard                    none         37            46            46
# 1  standard                    none        124           142           142
# 2  standard                    none        156           196           193
# 3  standard               completed         80            78            81
# 4  standard                    none        131           166           166
#
# Últimas 5 filas:
#                  names  gender race/ethnicity parental level of education  \
# 1395  Alexander Dillon    male        group D          associate's degree
# 1396    Marina Zeigler  female        group C           bachelor's degree
# 1397     Laurie Carter  female        group B            some high school
# 1398      Joseph Mccoy    male        group D                some college
# 1399      Amanda Perez  female        group A                 high school
#
#              lunch test preparation course math score reading score  \
# 1395      standard                    none        193           142
# 1396  free/reduced               completed         66            74
# 1397      standard               completed         54            61
# 1398  free/reduced                    none        193           196
# 1399      standard               completed         68            80
#
#      writing score
# 1395           193
# 1396            81
# 1397            62
# 1398           193
# 1399            76
#
# Muestreo aleatorio de 5 filas:
#               names  gender race/ethnicity parental level of education  \
# 443   Autumn Miller  female        group D                 high school
# 186      Lisa Forry  female        group E           bachelor's degree
# 26    Samuel Dougal    male        group C             master's degree
# 583  Maureen Robins  female        group C             master's degree
# 576   Albert Vaughn    male        group E                some college
#
#             lunch test preparation course math score reading score  \
# 443      standard                    none        196           NaN
# 186      standard               completed         79            81
# 26   free/reduced               completed         46            42
# 583      standard                    none        NaN           142
# 576  free/reduced               completed         87            74
#
#     writing score
# 443           193
# 186            82
# 26             46
# 583           193
# 576            70
# 4.- Descripción numérica del Dataframe:
#                  names  gender race/ethnicity parental level of education  \
# count             1400    1400           1400                        1400
# unique            1153       2              5                           6
# top     Robert Frazier  female        group C                some college
# freq                 3     723            452                         334
#
#            lunch test preparation course  math score  reading score  \
# count       1400                    1400        1360           1360
# unique         2                       2          96             88
# top     standard                    none         193            193
# freq         904                     898         120            117
#
#         writing score
# count            1353
# unique             92
# top               193
# freq              133
# 5.- Cantidad de valores nulos por columna:
# names                           0
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     40
# reading score                  40
# writing score                  47
# dtype: int64
# 6.- Cantidad de valores únicos por columna:
# names                          1153
# gender                            2
# race/ethnicity                    5
# parental level of education       6
# lunch                             2
# test preparation course           2
# math score                       96
# reading score                    88
# writing score                    92
# dtype: int64
# 7.- Presenta un total de 247 filas con nombres duplicados.
#
# 8.- Las filas con nombres duplicados son:
#                    names  gender race/ethnicity parental level of education  \
# 12         Rita Courtney  female        group B            some high school
# 81    Elizabeth Quintero  female        group B                some college
# 160    Michelle Gonzales  female        group B            some high school
# 170        Carla Mendoza  female        group D          associate's degree
# 176       Darlene Parker  female        group C          associate's degree
# ...                  ...     ...            ...                         ...
# 1385      James Crawford    male        group D             master's degree
# 1390     Gloria Bradford  female        group B                 high school
# 1393         Adam Romero    male        group C                 high school
# 1395    Alexander Dillon    male        group D          associate's degree
# 1398        Joseph Mccoy    male        group D                some college
#
#              lunch test preparation course math score reading score  \
# 12        standard                    none        193           193
# 81        standard                    none         82            85
# 160       standard               completed         60            70
# 170   free/reduced                    none         43            60
# 176       standard                    none         54            61
# ...            ...                     ...        ...           ...
# 1385      standard                    none        193           147
# 1390      standard                    none        124            64
# 1393      standard               completed        124           193
# 1395      standard                    none        193           142
# 1398  free/reduced                    none        193           196
#
#      writing score
# 12             193
# 81              87
# 160             74
# 170             58
# 176             58
# ...            ...
# 1385           131
# 1390           193
# 1393            49
# 1395           193
# 1398           193
#
# [247 rows x 9 columns]
# 9.- Boxplot de notas:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## 1.2 Limpieza de Datos [1 punto]
#
# <p align="center">
#   <img src="https://blogdatlas.files.wordpress.com/2020/07/datlas_mx_blog_limpieza_bds_data-scrubbing-service.gif">
# </p>

# %% [markdown]
# En base a lo realizado anteriormente, realice una limpieza de los dataset. Asuma los supuestos señalados en la pregunta anterior para limpiar el `DataFrame` y cree una función que le permita limpiar los datos. Habiendo limpiado el `DataFrame`, compruebe nuevamente los datos con la función creada en la sección 1.1.
#
# **To-Do:**
#
# - [ ] Crear función que permita limpiar el dataset.
# - [ ] Comprobar que no existen anomalías en los datos a traves de la función de la sección 1.1.
#
# **Hint**
#
# Puede ser útil los métodos ```.drop_duplicates()``` y ```.dropna()``` como también utilizar queries con máscaras booleanas.

# %% [markdown]
# **Respuesta:**

# %%
def clean_data(dataframe):
    df   = dataframe.copy()
    df   = df.mask((df.duplicated(subset=['names']))|(df['math score']>100)|(df['reading score']>100)|(df['writing score']>100)).dropna()
    return df

df_grades = clean_data(df_grades)
df_grades
# Out:
#                  names  gender race/ethnicity parental level of education  \
# 0        Rita Courtney  female        group B            some high school
# 3     Charles Linstrom    male        group A           bachelor's degree
# 5          Brian Young    male        group C            some high school
# 6       Howard Jimenez    male        group E            some high school
# 7         Wayne Wilson    male        group B            some high school
# ...                ...     ...            ...                         ...
# 1392     Richard Young    male        group D                 high school
# 1394     Wanda Russell  female        group B                 high school
# 1396    Marina Zeigler  female        group C           bachelor's degree
# 1397     Laurie Carter  female        group B            some high school
# 1399      Amanda Perez  female        group A                 high school
#
#              lunch test preparation course math score reading score  \
# 0         standard                    none         37            46
# 3         standard               completed         80            78
# 5         standard                    none         73            66
# 6         standard               completed         81            75
# 7         standard               completed         94            86
# ...            ...                     ...        ...           ...
# 1392      standard                    none         69            75
# 1394  free/reduced               completed         23            44
# 1396  free/reduced               completed         66            74
# 1397      standard               completed         54            61
# 1399      standard               completed         68            80
#
#      writing score
# 0               46
# 3               81
# 5               63
# 6               76
# 7               87
# ...            ...
# 1392            71
# 1394            36
# 1396            81
# 1397            62
# 1399            76
#
# [875 rows x 9 columns]

# %% [markdown]
# > Utilice la función creada en el punto 1.1 para verificar sus resultados.

# %% [markdown]
# **Justificación:**

# %% [markdown]
# ```
# Para poder filtrar los datos en funcion de los datos obtenidos duplicated, se usa mask con multicondiciones permitiendo eliminar los datos con valores sobre 100.
# ```

# %% [markdown]
# ## 1.3 Trabajando con Datos
#
# <p align="center">
#   <img src="https://media3.giphy.com/media/YQitE4YNQNahy/giphy-downsized-large.gif">
# </p>

# %% [markdown]
# ### 1.3.1 Transformación de notas a "Nota Chilena" [0.5 Puntos]

# %% [markdown]
# En una de las reuniones con Don Caguayo este les comenta su intención de pasar todas sus notas a la "Escala Chilena". Para esto les facilita la siguiente ecuación:
#
# $$Nota \, Chilena= \% \, de \, logro*0.06 + 1$$
#
# Utilizando la ecuación entregada, cree una función que le permita pasar a la escala Chilena las notas del dataframe y entregue las notas redondeadas al segundo decimal.
#
# **To-Do**
#
# - [ ] Tranforme los valores a la escala chilena.

# %% [markdown]
# **Respuesta:**

# %%
def nota_chilena(dataframe_in, columna):
    df  = dataframe_in.copy()
    df  = df.mask((df.duplicated(subset=['names']))|(df['math score']>100)|(df['reading score']>100)|(df['writing score']>100)).dropna()
    
    df[columna]  = df[columna]*0.06 + 1
    return df
df_grades = nota_chilena(df_grades,['math score','reading score','writing score'])
df_grades
# Out:
#                  names  gender race/ethnicity parental level of education  \
# 0        Rita Courtney  female        group B            some high school
# 3     Charles Linstrom    male        group A           bachelor's degree
# 5          Brian Young    male        group C            some high school
# 6       Howard Jimenez    male        group E            some high school
# 7         Wayne Wilson    male        group B            some high school
# ...                ...     ...            ...                         ...
# 1392     Richard Young    male        group D                 high school
# 1394     Wanda Russell  female        group B                 high school
# 1396    Marina Zeigler  female        group C           bachelor's degree
# 1397     Laurie Carter  female        group B            some high school
# 1399      Amanda Perez  female        group A                 high school
#
#              lunch test preparation course math score reading score  \
# 0         standard                    none       3.22          3.76
# 3         standard               completed        5.8          5.68
# 5         standard                    none       5.38          4.96
# 6         standard               completed       5.86           5.5
# 7         standard               completed       6.64          6.16
# ...            ...                     ...        ...           ...
# 1392      standard                    none       5.14           5.5
# 1394  free/reduced               completed       2.38          3.64
# 1396  free/reduced               completed       4.96          5.44
# 1397      standard               completed       4.24          4.66
# 1399      standard               completed       5.08           5.8
#
#      writing score
# 0             3.76
# 3             5.86
# 5             4.78
# 6             5.56
# 7             6.22
# ...            ...
# 1392          5.26
# 1394          3.16
# 1396          5.86
# 1397          4.72
# 1399          5.56
#
# [875 rows x 9 columns]

# %% [markdown]
# ### 1.3.2 Obtención de promedio de alumnos [0.5]

# %% [markdown]
# Con todas las notas adjuntadas, la prestigiosa Universidad De la Cachaña necesita obtener el promedio general de cada uno de los alumnos. Para esto se le solicita que calcule el promedio con cada una de las asignaturas y el promedio se anexe como una nueva columna al final del `DataFrame` original. Cabe señalar que las notas deben ser redondeadas al segundo decimal.
#
# **To-Do:**
# - [ ] Crear función que nos permite obtener el promedio de cada uno de los alumnos y anexar esta información en el `DataFrame` original.

# %% [markdown]
# **Respuesta:**

# %%
def alumnos_promedio(dataframe_in):
    df = dataframe_in.copy()
    df['GPA'] = (df['math score'] + df['reading score'] + df['writing score'])/3
    return df

# %% [markdown]
# **Respuesta Esperada:**

# %%
df_grades = alumnos_promedio(df_grades)
df_grades.head()
# Out:
#               names  gender race/ethnicity parental level of education  \
# 0     Rita Courtney  female        group B            some high school
# 3  Charles Linstrom    male        group A           bachelor's degree
# 5       Brian Young    male        group C            some high school
# 6    Howard Jimenez    male        group E            some high school
# 7      Wayne Wilson    male        group B            some high school
#
#       lunch test preparation course math score reading score writing score  \
# 0  standard                    none       3.22          3.76          3.76
# 3  standard               completed        5.8          5.68          5.86
# 5  standard                    none       5.38          4.96          4.78
# 6  standard               completed       5.86           5.5          5.56
# 7  standard               completed       6.64          6.16          6.22
#
#     GPA
# 0  3.58
# 3  5.78
# 5  5.04
# 6  5.64
# 7  6.34

# %% [markdown]
# ### 1.3.3 Reprobados y Destacados [1.5 Punto, 0.5 Cada DataFrame]

# %% [markdown]
# Contentos con su desempeño, la Universidad les solicita que obtengan los alumnos quienes han reprobado el año y los que han tenido desempeño de destacado. Para esto se considerará que un alumno ha reprobado el año cuando el promedio de notas es inferior a 4.0 en la Escala Chilena, y se considerará destacado si posee notas superiores a 5.8 en todas las asignaturas (o sea notas superiores a 5.8 en `math score`, `reading score` y `writing score`).
#
# Cree una función que permita obtener tres Dataframes:
# - El primero deberá poseer solamente los alumnos que han reprobado en la prestigiosa universidad.
# - El segundo debe entregar un DataFrame similar al original, pero marcado con una "R" el promedio de notas de los alumnos reprobados.
# - El tercero será un Data Frame con los alumnos destacados ordenados de mayor a menor.
#
# **To-Do:**
#
# - [ ] Obtener DataFrame con los alumnos que reprobaron el año.
# - [ ] Obtener DataFrame similar al original, pero marcados con una "R" el atributo GPA de los alumnos reprobados.
# - [ ] Obtener DataFrame con los alumnos destacados ordenados de mayor a menor.

# %% [markdown]
# **Respuesta:**

# %%
def reprobados_destacados(dataframe_in):
    df = dataframe_in.copy()
    df1 = df[df['GPA'] < 4]
    df2 = df.copy()
    df2.loc[df['GPA'] < 4,'GPA'] = 'R'
    df3 = df[(df['math score']>5.8) & (df['reading score']>5.8) & (df['writing score']>5.8)]
    
    return df1,df2,df3

# %%
dataframe1, dataframe2, dataframe3 = reprobados_destacados(df_grades)
dataframe1
# Out:
#                 names  gender race/ethnicity parental level of education  \
# 0       Rita Courtney  female        group B            some high school
# 13        Mikki Amaya  female        group A                 high school
# 26      Samuel Dougal    male        group C             master's degree
# 55    Rodger Talavera    male        group B                 high school
# 63     Morris Johnson    male        group A          associate's degree
# ...               ...     ...            ...                         ...
# 1371   Charles Harian    male        group C            some high school
# 1373    Wendy Gunnell  female        group D            some high school
# 1389      Diana Costa  female        group C                 high school
# 1391      Amy Sieving  female        group C                 high school
# 1394    Wanda Russell  female        group B                 high school
#
#              lunch test preparation course math score reading score  \
# 0         standard                    none       3.22          3.76
# 13    free/reduced               completed       3.04          3.88
# 26    free/reduced               completed       3.76          3.52
# 55    free/reduced                    none       3.16          2.74
# 63    free/reduced               completed        3.4           4.3
# ...            ...                     ...        ...           ...
# 1371  free/reduced               completed        3.7          4.12
# 1373  free/reduced                    none       2.62          3.04
# 1389  free/reduced                    none       3.46          3.76
# 1391      standard                    none       2.74          2.74
# 1394  free/reduced               completed       2.38          3.64
#
#      writing score   GPA
# 0             3.76  3.58
# 13            3.46  3.46
# 26            3.76  3.68
# 55            2.62  2.84
# 63            4.18  3.96
# ...            ...   ...
# 1371          3.94  3.92
# 1373          2.92  2.86
# 1389          3.58   3.6
# 1391           2.8  2.76
# 1394          3.16  3.06
#
# [86 rows x 10 columns]

# %%
dataframe2
# Out:
#                  names  gender race/ethnicity parental level of education  \
# 0        Rita Courtney  female        group B            some high school
# 3     Charles Linstrom    male        group A           bachelor's degree
# 5          Brian Young    male        group C            some high school
# 6       Howard Jimenez    male        group E            some high school
# 7         Wayne Wilson    male        group B            some high school
# ...                ...     ...            ...                         ...
# 1392     Richard Young    male        group D                 high school
# 1394     Wanda Russell  female        group B                 high school
# 1396    Marina Zeigler  female        group C           bachelor's degree
# 1397     Laurie Carter  female        group B            some high school
# 1399      Amanda Perez  female        group A                 high school
#
#              lunch test preparation course math score reading score  \
# 0         standard                    none       3.22          3.76
# 3         standard               completed        5.8          5.68
# 5         standard                    none       5.38          4.96
# 6         standard               completed       5.86           5.5
# 7         standard               completed       6.64          6.16
# ...            ...                     ...        ...           ...
# 1392      standard                    none       5.14           5.5
# 1394  free/reduced               completed       2.38          3.64
# 1396  free/reduced               completed       4.96          5.44
# 1397      standard               completed       4.24          4.66
# 1399      standard               completed       5.08           5.8
#
#      writing score   GPA
# 0             3.76     R
# 3             5.86  5.78
# 5             4.78  5.04
# 6             5.56  5.64
# 7             6.22  6.34
# ...            ...   ...
# 1392          5.26   5.3
# 1394          3.16     R
# 1396          5.86  5.42
# 1397          4.72  4.54
# 1399          5.56  5.48
#
# [875 rows x 10 columns]

# %%
dataframe3
# Out:
#                  names  gender race/ethnicity parental level of education  \
# 7         Wayne Wilson    male        group B            some high school
# 35     Shanna Braswell  female        group D           bachelor's degree
# 43       Thelma Yeates  female        group E          associate's degree
# 78      Natalie Turney  female        group E          associate's degree
# 84     Dennis Campbell    male        group C             master's degree
# ...                ...     ...            ...                         ...
# 1318        James King    male        group B                some college
# 1352     Sandra Pompey  female        group E          associate's degree
# 1359      Earnest Cole    male        group D                some college
# 1368  Charles Herandez    male        group D             master's degree
# 1381   Robert Morrison    male        group D                some college
#
#              lunch test preparation course math score reading score  \
# 7         standard               completed       6.64          6.16
# 35    free/reduced               completed       6.58           7.0
# 43    free/reduced               completed       5.98          6.16
# 78        standard                    none        6.1          6.52
# 84        standard               completed       6.46           6.1
# ...            ...                     ...        ...           ...
# 1318      standard               completed       6.46          6.76
# 1352      standard                    none        7.0           7.0
# 1359      standard               completed       5.92          5.92
# 1368  free/reduced               completed       6.04          6.34
# 1381      standard               completed        7.0          6.82
#
#      writing score   GPA
# 7             6.22  6.34
# 35             7.0  6.86
# 43            6.28  6.14
# 78             6.1  6.24
# 84             6.1  6.22
# ...            ...   ...
# 1318          6.46  6.56
# 1352           7.0   7.0
# 1359          6.28  6.04
# 1368           6.4  6.26
# 1381          6.94  6.92
#
# [94 rows x 10 columns]

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ```
# Escriba aqui su respuesta
# ```

# %% [markdown]
# ### 1.3.4 Consultas de Alumnos [0.5 Puntos]

# %% [markdown]
# Algunos padres (extremadamente entrometidos y...) preocupados por el desempeño de sus hijos, desean saber estos han aprobado o no el año. Como la tarea de buscar a mano cada uno de estos alumnos en el `DataFrame` resulta demasiado tedioso, el rector le solicita crear una función que tenga como entrada el `DataFrame` donde se realizará la busqueda y una lista con los nombres de los alumnos, luego la función deberá retornar un `DataFrame` con los nombres de los alumnos y el promedio general de cada uno.
#
# Creada la función busque el promedio general de los siguientes alumnos en el segundo Data frame creado en la sección 1.3.3:
#
# `['Lucille Stanphill','Marcus Mcfarland', 'Matthew Freeman', 'Dana Mojica', 'Paul Hyder', 'Jeffrey Korn', 'Robert Strain',
# 'Ronald Jett', 'Lorena Reed', 'Hazel Posey']`
#
# **Hint:** Puede serle de utilidad utilizar `isin()`.

# %% [markdown]
# **Respuesta:**

# %%
def consulta_gpa(dataframe_in, lista_alumnos):
    df = dataframe_in.copy()
    df = df[df['names'].isin(lista_alumnos)][['names','GPA']]
    return df


lista_alumnos = [
    "Lucille Stanphill",
    "Marcus Mcfarland",
    "Matthew Freeman",
    "Dana Mojica",
    "Paul Hyder",
    "Jeffrey Korn",
    "Robert Strain",
    "Ronald Jett",
    "Lorena Reed",
    "Hazel Posey",
]
consulta_gpa(dataframe2, lista_alumnos)
# Out:
#                  names   GPA
# 198  Lucille Stanphill  5.94
# 372   Marcus Mcfarland  4.86
# 418    Matthew Freeman     R
# 421        Dana Mojica     R
# 675      Robert Strain   4.4
# 679        Ronald Jett     R
# 681        Hazel Posey     R
# 753        Lorena Reed     R

# %%
pd.qcut(df_grades['GPA'].values,q=5,labels =['Bajísimo', 'Bajo', 'Medio', 'Alto', 'Muy alto'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 pd.qcut(df_grades['GPA'].values,q=5,labels =['Bajísimo', 'Bajo', 'Medio', 'Alto', 'Muy alto'])
#
# File ~\Anaconda3\envs\sqm\lib\site-packages\pandas\core\reshape\tile.py:376, in qcut(x, q, labels, retbins, precision, duplicates)
#     373 quantiles = np.linspace(0, 1, q + 1) if is_integer(q) else q
#     375 x_np = np.asarray(x)
# --> 376 x_np = x_np[~np.isnan(x_np)]
#     377 bins = np.quantile(x_np, quantiles)
#     379 fac, bins = _bins_to_cuts(
#     380     x,
#     381     bins,
#    (...)
#     386     duplicates=duplicates,
#     387 )
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# ### 1.3.5 Quintiles de Rendimiento [0.5 Puntos]

# %% [markdown]
# El rector, intrigado por saber si existe una relación entre el nivel educacional de los padres y las notas de sus hijos les plantea estudiar dicha relación. Para esto, les solicita que desde el `DataFrame` que posee a todos los alumnos (`DataFrame` obtenido tras la limpieza), generen una nueva columna que clasifique en quintiles de rendimiento para sus alumnos: `['Bajísimo', 'Bajo', 'Medio', 'Alto', 'Muy alto']`. (investigar `qcut()`)
#
# Hecho esto, grafique a través de un scatter plot el nivel educacional de los padres v/s el promedio de los alumnos, utilice los cuantiles generados anteriormente para mostrar en que cuantil se encuentra cada uno de los datos.
#
# Realizado el grafico, responda la siguiente pregunta: **¿Es posible visualizar alguna tendencia en el gráfico?.**

# %% [markdown]
# **Respuesta:**

# %%
# Código para quintiles 
# La variable que contenga los quintiles debe llamarse GPA cuantiles para que el gráfico funcione.

df_grades['GPA cuantiles'] = pd.qcut(df_grades['GPA'].values,5,labels =['Bajísimo', 'Bajo', 'Medio', 'Alto', 'Muy alto'])

# Código de gráfico 
fig = px.scatter(
    df_grades.sort_values(by="GPA"),
    x="GPA",
    y="parental level of education",
    hover_data=["gender"],
    color="GPA cuantiles",
    title="GPA por Nivel de educación de los padres",
    color_discrete_sequence=["tomato", "orange", "yellow", "greenyellow", "green"]
)

fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 3
#       1 # Código para quintiles
#       2 # La variable que contenga los quintiles debe llamarse GPA cuantiles para que el gráfico funcione.
# ----> 3 df_grades['GPA cuantiles'] = pd.qcut(df_grades['GPA'].values(),5,labels =['Bajísimo', 'Bajo', 'Medio', 'Alto', 'Muy alto'])
#       5 # Código de gráfico
#       6 fig = px.scatter(
#       7     df_grades.sort_values(by="GPA"),
#       8     x="GPA",
#    (...)
#      13     color_discrete_sequence=["tomato", "orange", "yellow", "greenyellow", "green"]
#      14 )
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# ```
# Escriba aqui su respuesta
# ```

# %% [markdown]
# # Conclusión
# Eso ha sido todo para el lab de hoy, recuerden que el laboratorio tiene un plazo de entrega de una semana. Cualquier duda del laboratorio, no duden en contactarnos por mail o U-cursos.
#
# <p align="center">
#   <img src="https://gifdb.com/images/high/orange-cat-cat-walking-with-two-legs-xlgf7qx4i24da74f.gif" width="400">
# </p>

# %% [markdown]
# <br>
# <center>
# <img src="https://i.kym-cdn.com/photos/images/original/001/194/195/b18.png" width=100 height=50 />
# </center>
# <br>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=87110296-876e-426f-b91d-aaf681223468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
