# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - \<Primer integrante\> Benjamin Constant
# - \<Segundo integrante\>
#
#
# ### Link de repositorio de GitHub: `\<https://github.com/BenConstant/MDS7202lab_Benjamin_Constant/blob/main/Proyecto/Proyecto_enunciado.ipynb\>`
#
# Fecha límite de entrega 📆: 27 de Octubre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA_fecha/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `Profiler`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por imcompatibilidades de librerías no será corregido.**

# %%
# Libreria Core del lab.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from IPython.display import HTML
from scipy import sparse

# Libreria para plotear (En colab esta desactualizado plotly)
#!pip install --upgrade plotly
import plotly.express as px
import plotly.graph_objects as go
import missingno as msno

# Librerias utiles
from sklearn.manifold        import TSNE
from sklearn.cluster         import KMeans
from sklearn.base            import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split 
from sklearn.pipeline        import Pipeline
from sklearn.compose         import ColumnTransformer
from sklearn.preprocessing   import FunctionTransformer, OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, PowerTransformer
from sklearn.metrics         import confusion_matrix
from sklearn.impute import SimpleImputer

# %%
import os
import datetime
from   pathlib import Path
import re
from scipy.stats import zscore
class Profiler():
    columnas_sinNaN = []
    feature_anomala = []
    def __init__(self,dataframe):
        if isinstance(dataframe, pd.DataFrame):
            self.df        = dataframe
            self.fecha_hoy = datetime.datetime.now().strftime("%d_%m_%Y")
            self.nombre_carpeta_fecha ="EDA_" + self.fecha_hoy
            if not os.path.exists(self.nombre_carpeta_fecha):
                os.makedirs(self.nombre_carpeta_fecha)  
        else:
            raise TypeError(
                "Se debe entregar un archivo Dataframe")
            
    def summarize(self):
        df                   = self.df.copy()
        
        solo_numeros = df.select_dtypes(include=np.number)
        solo_str     = df.select_dtypes(include='object')
        
        with open(self.nombre_carpeta_fecha + '\summary.txt','w') as archivo:
    
            for nombre_column in solo_str.columns:
        
                df_new = pd.DataFrame(solo_str[nombre_column].fillna('Valores nulos').value_counts(dropna=False))
                anomalia = [indice for indice in df_new.index if len(re.split(r'(?![\d+.\d+])[^A-Za-z0-9]',indice))>2]
                if anomalia:
                    print('El feature '+nombre_column+' presenta simbolos poco comunes en los datos')
                    self.feature_anomala.append(nombre_column)
                    
                df_new.loc['total_unicos'] = df_new[df_new==1].sum()
                df_new.loc['dtype column'] = solo_str[nombre_column].dtype
                
                if not 'Valores nulos' in df_new.index:
                    df_new.loc['Valores nulos'] = 0
                    self.columnas_sinNaN.append(nombre_column)
                    
                archivo.write('----------Columnna Dataset: ' + nombre_column + '-----------------------\n')
                archivo.write(' \n')
                df_new.loc[['Valores nulos','total_unicos','dtype column'],:].to_csv(archivo,sep='\t',index=True)
                archivo.write(' \n')
            
            for nombre_column in solo_numeros.columns:
                
                df_new = pd.DataFrame(solo_numeros[nombre_column].describe())
                df_new.loc['Negativo'] = solo_numeros[nombre_column][solo_numeros[nombre_column]<0].sum()
                df_new.loc['Cero']     = solo_numeros[nombre_column][solo_numeros[nombre_column]==0].sum()
                q1 = solo_numeros[nombre_column].quantile(0.25)
                q3 = solo_numeros[nombre_column].quantile(0.25)
                iqr = q3-q1
                umbral_inf = q1 - 1.5*iqr
                umbral_sup = q3 + 1.5*iqr
                try:
                    df_new.loc['outliers'] = len(solo_numeros[nombre_column][(solo_numeros[nombre_column] < umbral_inf)|(solo_numeros[nombre_column]>umbral_sup)].dropna())
                except ValueError:
                    df_new.loc['outliers'] = 0
                    
                archivo.write('----------Columnna Dataset: ' + nombre_column + '-----------------------\n')
                archivo.write(' \n')
                df_new.to_csv(archivo,sep='\t',index=True)
                archivo.write(' \n')
      
    def plot_vars(self,variables_max=7):
        self.path_plots = self.nombre_carpeta_fecha + '\plots'
        
        if not os.path.exists(self.path_plots):
                os.makedirs(self.path_plots)
        df                   = self.df.copy()
        solo_numeros = df.select_dtypes(include=np.number)
        solo_str     = df.select_dtypes(include='object')   
        
        numeros = pd.DataFrame(solo_numeros.value_counts())
        fig, axs= plt.subplots(figsize=(7,4),tight_layout=True,facecolor='w')
        axs.hist(solo_numeros)
        axs.set_ylabel('Count [-]',fontsize=15,fontname='serif')
        axs.set_xlabel('Años', fontsize=15,fontname='serif')
        axs.set_title('Years',fontsize=15,fontname='serif')
        plt.savefig(self.path_plots+ "\correlacion_numero.pdf", format="pdf",bbox_inches='tight')
        
        for nombre_column in solo_str.columns:
            
            df_new           = solo_str[nombre_column].value_counts().sort_values()
            filtro_categoria = df_new.head(variables_max).index 
            df_new_filtrado = solo_str[solo_str[nombre_column].isin(filtro_categoria)]

            df_plot = pd.DataFrame(df_new_filtrado[nombre_column].value_counts())
            
            fig, ax = plt.subplots(figsize=(7,4),tight_layout=True,facecolor='w')
            ax.bar(df_plot.index,df_plot[nombre_column])
            ax.set_ylabel('Count [-]',fontsize=10,fontname='serif')
            name_resumen = ['\n'.join(texto.split(' ')) for texto in df_plot.index]
            ax.set_xticklabels(name_resumen,rotation=45,fontsize=7)
            for tick in ax.xaxis.get_major_ticks():
                tick.set_pad(20)
    
            plt.savefig(self.path_plots+ str("\\") + nombre_column+ ".pdf", format="pdf",bbox_inches='tight')
        enc = OrdinalEncoder()
        ordinales = enc.fit_transform(solo_str.dropna())
        
        correlacion = pd.DataFrame(ordinales,columns=solo_str.columns).corr()
        
        fig, ax = plt.subplots(figsize=(9, 7))

        heatmap = ax.imshow(correlacion, cmap='viridis', vmin=-1, vmax=1, aspect='auto')
        cbar = fig.colorbar(heatmap)
        ax.set_xticklabels(correlacion.columns)
        ax.set_yticklabels(correlacion.columns)
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
        plt.title("Correlación entre Variables")
        plt.savefig(self.path_plots+ "\correlacion_cat.pdf", format="pdf",bbox_inches='tight')
        
    def clean_data(self,all_drop=False):
        self.path_clean = self.nombre_carpeta_fecha + '\clean_data'
        
        if not os.path.exists(self.path_clean):
                os.makedirs(self.path_clean)
                
        df           = self.df.copy()
        solo_numeros = df.select_dtypes(include=np.number)
        solo_str     = df.select_dtypes(include='object')
        
        drop_df_total  = df.dropna()
        
        enc             = OrdinalEncoder()
        ordinales       = enc.fit_transform(solo_str.dropna())
        correlacion_str = pd.DataFrame(ordinales,columns=solo_str.columns).corr()
        #corre_filtro    = pd.DataFrame(correlacion_str.sum())[correlacion_str.sum()<0.5].drop(self.columnas_sinNaN)
        #if not len(corre_filtro)<1:
        #    solo_str_filtro = solo_str[solo_str[corre_filtro.index].notna()]
   
        pipeline_final = Pipeline([
                ('limpiar_separacion',FunctionTransformer(func=limpiar_separacion)),
                ('Separar',FunctionTransformer(func=separar))
                ])
    
        Transf_conv    = FunctionTransformer(func=cambio_float)
        
        df[['age','height','weight']] = pipeline_final.fit_transform(df['age-height-weight'])

        df['age']    = Transf_conv.transform(df['age'])
        df['height'] = Transf_conv.transform(df['height'])
        df['weight'] = Transf_conv.transform(df['weight'])
        
        df = df.drop(columns='age-height-weight')
        
        df = df[df['age'].notna()]
        self.path_data = self.path_clean + '\data.csv'
        if all_drop:
            drop_df_total.to_csv(self.path_clean + '\data.csv')
        else:
            df.to_csv(self.path_clean + '\data.csv')
        
            
    def scale(self,scaler=MinMaxScaler(),numTransf=PowerTransformer(method='yeo-johnson'),Imputer=SimpleImputer(strategy="constant", fill_value="missing"),catTransf=OrdinalEncoder()):
        self.path_scale = self.nombre_carpeta_fecha + '\scale'
        if not os.path.exists(self.path_scale):
                os.makedirs(self.path_scale)
                
        df = pd.read_csv(self.path_data).set_index('ID')
        solo_numeros = df.select_dtypes(include=np.number)
        solo_str     = df.select_dtypes(include='object')
        
        number = Pipeline([('scaler', scaler),
                    ('yeo-johnson', numTransf) ])
        categ = Pipeline(
                steps=[
                        ("imputer_cat", Imputer),
                        ("OrdinalEncoder", catTransf),
                        ])
        
        preprocessor = ColumnTransformer(
                        transformers=[
                            ('number',number,solo_numeros.columns),
                            ('Categ',categ,solo_str.columns)
                            ])
        df_new = pd.DataFrame(preprocessor.fit_transform(df),columns=df.columns)

        self.path_scale_df = self.path_scale + '\scaled_features.csv'
        df_new.to_csv(self.path_scale_df)
        
    def make_clusters(self,clustering = KMeans):
        self.path_cluster = self.nombre_carpeta_fecha + '\clusters'
        if not os.path.exists(self.path_cluster):
                os.makedirs(self.path_cluster)
        df           = pd.read_csv(self.path_scale_df)
        
        intertias = [
                [i,KMeans(n_clusters=i,random_state=0).fit(df.dropna()).inertia_]
                for i in range(2,20)
                ]
        fig, ax = plt.subplots(figsize=(9, 7))
        intertias = pd.DataFrame(intertias, columns=["n° clusters", "inertia"])
        ax.plot(intertias['n° clusters'],intertias['inertia'])
        ax.set_xlabel('n cluster')
        ax.set_ylabel('intertia')
        
        plt.savefig(self.path_cluster + "\codos.pdf", format="pdf",bbox_inches='tight')
        #px.line(intertias,x="n° clusters",y="inertia",title="Método del Codo",height=600,            )
        
        # Por el largo de los datos y mi notebook, reducire el df para que corra el modelo mas rapido
        tsn  = TSNE(n_components=2, random_state=0)
        df_drop = df.dropna()
        df_short = df_drop[:20000]
        df_tsne = tsn.fit_transform(df_short)
        kmean = clustering(n_clusters=8,random_state=0).fit(df_short)
        df_short['Cluster'] = kmean.labels_
        df_short['x_tsne']  = df_tsne[:,0]
        df_short['y_tsne']  = df_tsne[:,1]
        fig, ax = plt.subplots(figsize=(9, 7))
        clust = ax.scatter(df_short['x_tsne'],df_short['y_tsne'],c=df_short['Cluster'])
        cbar = fig.colorbar(clust)
        ax.set_xlabel('x_tsne')
        ax.set_ylabel('y_tsne')
        plt.savefig(self.path_cluster + "\cluster.pdf", format="pdf",bbox_inches='tight')
        df_short.to_csv(self.path_cluster +'\data_clusters.csv')
        
    def detect_anomalies(self,metodo=zscore()):
        self.path_anomalias = self.nombre_carpeta_fecha + '\Anomalies'
        if not os.path.exists(self.path_anomalias):
                os.makedirs(self.path_anomalias)
        df   = pd.read_csv(self.path_scale_df)
        df   = df.dropna()
        anomalia_pipe = Pipeline([
            ('z_score',metodo)
        ],remainder='passthrough')
        preproccess = ColumnTransformer([
            ('all_values',anomalia_pipe,df.columns)
        ])
        df_anom = pd.DataFrame(preproccess.fit_transform(df),columns=df.columns)
        df_anom.to_csv(self.path_anomalias + '\data_anomalies.csv')
        
    def profile(self):
        self.summarize()
        self.plot_vars()
        self.clean_data()
        self.scale()
        self.make_clusters()
        self.detect_anomalies()
        
    def clearGarbage(self):
        for filename in os.listdir():
            if not len(filename.split('.'))>1:
                # Este codigo funciona si se tiene permiso para controlar la carpeta, sino sale un error WinErrir 5
                os.remove(os.path.join(Path.cwd(),filename))
    
def limpiar_separacion(Serie):
    return Serie.apply(lambda x: '-'.join(re.split(r'(?![\d+.\d+])[^A-Za-z0-9]',x)))
def cambio_float(Serie):
    return Serie.apply(lambda x: float(x) if x != 'nan' else np.nan)
def separar(Serie):
    return Serie.str.split('-',expand=True)
def log_transform(x):
    return np.log(x + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 6
#       4 import re
#       5 from scipy.stats import zscore
# ----> 6 class Profiler():
#       7     columnas_sinNaN = []
#       8     feature_anomala = []
#
# Cell In[53], line 222, in Profiler()
#     219     plt.savefig(self.path_cluster + "\cluster.pdf", format="pdf",bbox_inches='tight')
#     220     df_short.to_csv(self.path_cluster +'\data_clusters.csv')
# --> 222 def detect_anomalies(self,metodo=zscore()):
#     223     self.path_anomalias = self.nombre_carpeta_fecha + '\Anomalies'
#     224     if not os.path.exists(self.path_anomalias):
#
# TypeError: zscore() missing 1 required positional argument: 'a'

# %%
dataframe = pd.read_parquet("olimpiadas.parquet")
dataframe = dataframe.set_index('ID')
dataframe
# Out:
#                             Name Sex            Team  NOC        Games  Year  \
# ID
# 1                      A Dijiang   M           China  CHN  1992 Summer  1992
# 2                       A Lamusi   M           China  CHN  2012 Summer  2012
# 3            Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  1920
# 4           Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  1900
# 5       Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  1988
# ...                          ...  ..             ...  ...          ...   ...
# 135569                Andrzej ya   M        Poland-1  POL  1976 Winter  1976
# 135570                  Piotr ya   M          Poland  POL  2014 Winter  2014
# 135570                  Piotr ya   M          Poland  POL  2014 Winter  2014
# 135571        Tomasz Ireneusz ya   M          Poland  POL  1998 Winter  1998
# 135571        Tomasz Ireneusz ya   M          Poland  POL  2002 Winter  2002
#
# ...

# %%
clase_df = Profiler(dataframe)

# %%
clase_df.profile()
# Out:
# El feature Name presenta simbolos poco comunes en los datos
# El feature Team presenta simbolos poco comunes en los datos
# El feature City presenta simbolos poco comunes en los datos
# El feature Sport presenta simbolos poco comunes en los datos
# El feature Event presenta simbolos poco comunes en los datos
# El feature age-height-weight presenta simbolos poco comunes en los datos
# C:\Users\bnjac\AppData\Local\Temp\ipykernel_11084\2107174297.py:97: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(name_resumen,rotation=45,fontsize=7)
# C:\Users\bnjac\AppData\Local\Temp\ipykernel_11084\2107174297.py:97: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(name_resumen,rotation=45,fontsize=7)
# C:\Users\bnjac\AppData\Local\Temp\ipykernel_11084\2107174297.py:97: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#     - Se proporcionará una breve descripción del problema que estamos abordando y se explicará la metodología que se seguirá.
#
# Elaborar una breve introducción con todo lo necesario para entender qué realizarán durante su proyecto. La idea es que describan de manera formal el proyecto con sus propias palabras y logren describir algunos aspectos básicos tanto del dataset como del análisis a realizar sobre los datos.
#
# Por lo anterior, en esta sección ustedes deberán ser capaces de:
#
# - Describir la tarea asociada al dataset.
# - Describir brevemente los datos de entrada que les provee el problema.
# - Plantear hipótesis de cómo podrían abordar el problema.
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Se discutirán las observaciones y conclusiones obtenidas acerca de los datos proporcionados. A lo largo de su respuesta, debe responder preguntas como:
#         - ¿Como se comportan las variables numéricas? ¿y las categóricas?
#         - ¿Existen valores nulos en el dataset? ¿En qué columnas? ¿Cuantos?
#         - ¿Cuáles son las categorías y frecuencias de las variables categóricas?
#         - ¿Existen datos duplicados en el conjunto?
#         - ¿Existen relaciones o patrones visuales entre las variables?
#         - ¿Existen anomalías notables o preocupantes en los datos?
# 3. Creación de Clusters y Anomalías
#     - Se justificará la elección de los algoritmos a utilizar y sus hiperparámetros. En el caso de clustering, justifique además el número de clusters.
#
# 4. Análisis de Resultados
#     - Se examinarán los resultados obtenidos a partir de los clústers y anomalías generadas. ¿Se logra una separación efectiva de los datos? Entregue una interpretación de lo que representa cada clúster y anomalía.
# 5. Conclusión
#     - Se resumirán las principales conclusiones del análisis y se destacarán las implicaciones prácticas de los resultados obtenidos.

# %% [markdown]
# Introduccion
# El proyecto consiste en generar una clase que permita automatizar el control y analisis de una base de datos, en este caso de la base de datos de los juegos olimpicos, para poder obtener un analisis estadistico mas detallado sin errores presentes en la misma base de datos.
# La base de datos tiene los siguientes features:
# 1) ID: numero indice de cada fila en el dataset
# 2) Name: Nombres de los participantes
# 3) Sex: Orientacion sexual de los participantes
# 4) Team: Pais de origen o que representa del participante
# 5) NOC: Abreviatura del pais que representa
# 6) Games: Año y epoca del año de la realizacion de la olimpiada
# 7) Year: Año de la realizacion de la olimpiada
# 8) Season: Epoca del año de la realizacion de la olimpiada
# 9) City: Ciudad en donde se realiza la actividad en la que se va a participar
# 10) Sport: Deporte en el que la persona participo
# 11) Event: Evento en el que la persona participo
# 12) Medal: Medalla obtenida por la participacion por la persona
# 13) age-height-weight : Da la informacion sobre la edad, altura y peso del participante
#
# En base a estos datos, se pide encontrar anomalias o casos fuero de lugar para poder trabajar sobre ellos.
#
# Para abordar este tema, primero se debe analizar dato por dato para ver si presenta valores vacios, valores unicos que se asimilan a otros valores repetitivos y si los valores vacios se encuentran "escondidos" de otra forma. Para mejorar el analisis, lo mejor es separar en un inicio los datos numericos de los categoricos, para facilitar el manejo de los datos sin saber mucho de ellos.
#
# En los valores numericos
# Solo se encontro una columna, siendo la columna Year, lo cual su analisis fue bastante simple debido a que no presentaba valores extraños ni datos faltantes (Ver summary.txt)
# Para los valores categoricos
# Gran parte de los datos eran categoricos, siendo solo la columna Medal la que tenia una gran cantidad de medallas faltantes, alrededor de 231333. Esto se puede deber a que estos participantes no ganaron medallas, por lo que podria explicarse la ausencia de sus datos.
# En esta base de datos no existen valores duplicados, pero se puede deber a que algunos datos pudieran presentar errores en alguna categoria como la columna age-height-weight, que fue la que presenta valores unicos muy extraños como nan?nan*-nan, por lo que se debe realizar un analisis postumo sobre este duplicado.
#
# Existen relaciones entre las variables claras como entre el Team y el NOC y Sport y Event muy positivas, por lo que se pueden trabajar para arreglar los datos como muestra la figura guardada en correlacion_cat.pdf
# Tambien existen patrones entre las columnas, una entrega una informacion similar a la otra como Sport-Event, Games-Year-Season o Team-NOC, por lo que se podrian eliminar las columnas que presenten mayor variabilidad y asi facilitar el analisis
#
# Una vez obtenido un analisis preliminar, se comienza con la limpieza de los datos y normalizacion de estos, en especial con la columna age-height-weight, la cual presenta valores extraños, por lo que primero se separaran en columnas distintas y luego se analisan con los datos faltantes. Por otro lado, los datos categoricos debieron ser transformados a numericos para facilitar el analisis del conjunto de datos total, lo cual facilito procesamientos posteriores.
#
# Debido a la capacidad del notebook, se debio acotar los datos para facilitar la rapidez de los cluster y asi obtener agrupamientos de datos adecuados. Se eligio un numero de 8 cluster debido a que permite un mejor analisis de los datos segun el grafico de codo, ademas sabemos que algunas columnas se relacionan entre si muy directamente, por lo que fue la mejor idea.
#
# Se generan los cluster y las separaciones del conjunto de datos pero usando las columnas categoricas como numeros, facilitando el proceso. Se puede apreciar que se presentan filas o datos bien ordenados en filas y conjuntos bien aglomerados pero algunos tienden a perderse o mezclarce con otros conjuntos pero son solo los datos extremos.
#
# En conclusion, el analisis no fue tan automatizado debido a que se esperaban algunas columnas de entradas para mejorar el analisis. Ademas, en el analisis del cluster, para poder obtener resultados (en mi computador) se acotaron por lo que si se pudiera correr el codigo en un computador mas potente, quizas la agrupacion de datos sea generada de mejor manera.
